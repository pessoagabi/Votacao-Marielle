# %%
import csv
import pandas as pd
import numpy as np

# %%
tabela = pd.read_csv("votacao-rj.csv", dtype={'zona':np.str}, sep =";", encoding="latin-1")

# %%
tabela.head()
# Out:
#         municipio zona            candidato     cargo candidatura  situacao  \
# 0  RIO DE JANEIRO    1         ALAN MACHADO  VEREADOR    DEFERIDO  SUPLENTE
# 1  RIO DE JANEIRO    1       CAROLINA CACAU  VEREADOR    DEFERIDO  SUPLENTE
# 2  RIO DE JANEIRO    1  ANA ELIZA GUIMARÌES  VEREADOR    DEFERIDO  SUPLENTE
# 3  RIO DE JANEIRO    1         ANDR BARROS  VEREADOR    DEFERIDO  SUPLENTE
# 4  RIO DE JANEIRO    1       ANTïNIO JòNIOR  VEREADOR    DEFERIDO  SUPLENTE
#
#   partido                    nome_partido   coligcao2  votos
# 0    PSOL  Partido Socialismo e Liberdade  PSOL / PCB      3
# 1    PSOL  Partido Socialismo e Liberdade  PSOL / PCB     14
# 2    PSOL  Partido Socialismo e Liberdade  PSOL / PCB      2
# 3    PSOL  Partido Socialismo e Liberdade  PSOL / PCB     19
# 4    PSOL  Partido Socialismo e Liberdade  PSOL / PCB      3

# %%
tabela_agg = tabela.groupby(['zona','candidato']).agg({'votos': sum}).sort_values(by='votos', ascending = False).reset_index()

# %%
tabela_agg.head(100)
# Out:
#    zona               candidato  votos
# 0    25          WILLIAN COELHO  11081
# 1    22          ROSA FERNANDES  10749
# 2   120           ROGERIO ROCAL   9988
# 3   122                    ZICO   9701
# 4   188          TERESA BERGHER   8256
# 5   161                     DEL   8058
# 6   246            EDSON ZANATA   7728
# 7   179        CHIQUINHO BRAZÌO   6811
# 8   161          TERESA BERGHER   6206
# 9   246       JUNIOR DA LUCINHA   6160
# 10   23             ZICO BACANA   5782
# 11   22                     VAL   5463
# 12  123       PROFESSOR ADALMIR   5333
# 13  177          ROSA FERNANDES   5287
# 14  245       JUNIOR DA LUCINHA   5270
# 15  242       JUNIOR DA LUCINHA   5232
# 16  218               VERA LINS   5104
# 17  219    JAIR DA MENDES GOMES   5004
# 18  231                JAIRINHO   4979
# 19  219          ROSA FERNANDES   4793
# 20  240       JUNIOR DA LUCINHA   4743
# 21  125       JUNIOR DA LUCINHA   4706
# 22  180        CHIQUINHO BRAZÌO   4696
# ...

# %%
tabela_agg.shape
# Out:
# (155782, 3)

# %%
zona1 = tabela.loc[tabela['zona'] == '1']
zona1.head()
# Out:
#         municipio zona            candidato     cargo candidatura  situacao  \
# 0  RIO DE JANEIRO    1         ALAN MACHADO  VEREADOR    DEFERIDO  SUPLENTE
# 1  RIO DE JANEIRO    1       CAROLINA CACAU  VEREADOR    DEFERIDO  SUPLENTE
# 2  RIO DE JANEIRO    1  ANA ELIZA GUIMARÌES  VEREADOR    DEFERIDO  SUPLENTE
# 3  RIO DE JANEIRO    1         ANDR BARROS  VEREADOR    DEFERIDO  SUPLENTE
# 4  RIO DE JANEIRO    1       ANTïNIO JòNIOR  VEREADOR    DEFERIDO  SUPLENTE
#
#   partido                    nome_partido   coligcao2  votos
# 0    PSOL  Partido Socialismo e Liberdade  PSOL / PCB      3
# 1    PSOL  Partido Socialismo e Liberdade  PSOL / PCB     14
# 2    PSOL  Partido Socialismo e Liberdade  PSOL / PCB      2
# 3    PSOL  Partido Socialismo e Liberdade  PSOL / PCB     19
# 4    PSOL  Partido Socialismo e Liberdade  PSOL / PCB      3

# %%
zona1_agg = zona1.groupby(['candidato','partido','situacao']).agg({'votos': sum}).sort_values(by='votos', ascending = False).reset_index()
zona1_agg.head(20)
# Out:
#                   candidato partido          situacao  votos
# 0                     GUIGA      PR        NÌO ELEITO   1098
# 1          DR. JOÌO RICARDO    PMDB  ELEITO POR MDIA    444
# 2            TARCêSIO MOTTA    PSOL     ELEITO POR QP    401
# 3        BISPO INALDO SILVA     PRB     ELEITO POR QP    348
# 4          CARLOS BOLSONARO     PSC     ELEITO POR QP    334
# 5           ROSIETE MARINHO     PTN          SUPLENTE    303
# 6                CESAR MAIA     DEM     ELEITO POR QP    300
# 7        DR. CARLOS EDUARDO      SD     ELEITO POR QP    288
# 8          FERNANDO WILLIAM     PDT  ELEITO POR MDIA    254
# 9                   REIMONT      PT     ELEITO POR QP    227
# 10          MARIELLE FRANCO    PSOL     ELEITO POR QP    201
# 11         DENISE VIGILANTE     PMB        NÌO ELEITO    194
# 12            RAILDA FRANA     DEM          SUPLENTE    154
# 13           DANIEL MARTINS     PDT          SUPLENTE    148
# ...

# %%
zona2 = tabela.loc[tabela['zona'] == '2']
zona2.head()
# Out:
#            municipio zona            candidato     cargo candidatura  \
# 1606  RIO DE JANEIRO    2         ALAN MACHADO  VEREADOR    DEFERIDO
# 1607  RIO DE JANEIRO    2       CAROLINA CACAU  VEREADOR    DEFERIDO
# 1608  RIO DE JANEIRO    2  ANA ELIZA GUIMARÌES  VEREADOR    DEFERIDO
# 1609  RIO DE JANEIRO    2         ANDR BARROS  VEREADOR    DEFERIDO
# 1610  RIO DE JANEIRO    2       ANTïNIO JòNIOR  VEREADOR    DEFERIDO
#
#       situacao partido                    nome_partido   coligcao2  votos
# 1606  SUPLENTE    PSOL  Partido Socialismo e Liberdade  PSOL / PCB      1
# 1607  SUPLENTE    PSOL  Partido Socialismo e Liberdade  PSOL / PCB     17
# 1608  SUPLENTE    PSOL  Partido Socialismo e Liberdade  PSOL / PCB      0
# 1609  SUPLENTE    PSOL  Partido Socialismo e Liberdade  PSOL / PCB     30
# 1610  SUPLENTE    PSOL  Partido Socialismo e Liberdade  PSOL / PCB      5

# %%
zona2_agg = zona2.groupby(['candidato','partido','situacao']).agg({'votos': sum}).sort_values(by='votos', ascending = False).reset_index()
zona2_agg.head(20)
# Out:
#              candidato partido          situacao  votos
# 0          PABLO MELLO      PP          SUPLENTE   4343
# 1           CESAR MAIA     DEM     ELEITO POR QP   1022
# 2   BISPO INALDO SILVA     PRB     ELEITO POR QP    972
# 3    THIAGO K. RIBEIRO    PMDB     ELEITO POR QP    960
# 4       TARCêSIO MOTTA    PSOL     ELEITO POR QP    924
# 5     CARLOS BOLSONARO     PSC     ELEITO POR QP    876
# 6         CHRIS AGUIAR     PTN          SUPLENTE    768
# 7       GALï FERNANDES     PTB          SUPLENTE    692
# 8          LORENZ MELO     PDT          SUPLENTE    517
# 9     ROBERTO MONTEIRO      PT          SUPLENTE    447
# 10        MARCELO ARAR     PTB     ELEITO POR QP    398
# 11  DR. CARLOS EDUARDO      SD     ELEITO POR QP    359
# 12     MARIELLE FRANCO    PSOL     ELEITO POR QP    324
# 13  MARCELLO SICILIANO     PHS     ELEITO POR QP    304
# 14             HELINHO     PRB          SUPLENTE    288
# 15    TELESMAR SAMPAIO     PMB        NÌO ELEITO    272
# ...

# %%
zona11 = tabela.loc[tabela['zona'] == '11']
zona11_agg = zona11.groupby(['candidato','partido','situacao']).agg({'votos': sum}).sort_values(by='votos', ascending = False).reset_index()
zona11_agg.head(20)
# Out:
#               candidato partido          situacao  votos
# 0        ROSA FERNANDES    PMDB     ELEITO POR QP   3049
# 1   ALEXANDRE ISQUIERDO     DEM     ELEITO POR QP   2140
# 2        TARCêSIO MOTTA    PSOL     ELEITO POR QP   1040
# 3             VERA LINS      PP     ELEITO POR QP    970
# 4      CARLOS BOLSONARO     PSC     ELEITO POR QP    945
# 5       MARCELO RIBEIRO     PRP        NÌO ELEITO    756
# 6            CESAR MAIA     DEM     ELEITO POR QP    653
# 7                SERJÌO      PP          SUPLENTE    462
# 8       MARIELLE FRANCO    PSOL     ELEITO POR QP    400
# 9           JOÌO CABRAL    PMDB          SUPLENTE    367
# 10       ULISSES MARINS     PMN          SUPLENTE    365
# 11  JOSE CARLOS MODESTO     PTC          SUPLENTE    279
# 12         JORGINHO SOS    PMDB          SUPLENTE    277
# 13   BISPO INALDO SILVA     PRB     ELEITO POR QP    264
# 14     PEDRO PAULO CRUZ    PSOL          SUPLENTE    237
# ...

# %%
zona21 = tabela.loc[tabela['zona'] == '21']
zona21_agg = zona21.groupby(['candidato','partido','situacao']).agg({'votos': sum}).sort_values(by='votos', ascending = False).reset_index()
zona21_agg.head(20)
# Out:
#                candidato partido          situacao  votos
# 0       LUCIANO MEDEIROS     DEM          SUPLENTE   2853
# 1           JORGINHO SOS    PMDB          SUPLENTE   2615
# 2     PROFESSOR CALVINHO     PSD          SUPLENTE   1867
# 3   JOÌO MENDES DE JESUS     PRB     ELEITO POR QP   1433
# 4         GESIEL O PINGO     PRP        NÌO ELEITO   1047
# 5            JOÌO CABRAL    PMDB          SUPLENTE   1013
# 6       CARLOS BOLSONARO     PSC     ELEITO POR QP    824
# 7               AMIGO D      PR        NÌO ELEITO    753
# 8       ROBERTO TEIXEIRA     PSD          SUPLENTE    684
# 9         ROSA FERNANDES    PMDB     ELEITO POR QP    597
# 10    DR. CARLOS EDUARDO      SD     ELEITO POR QP    585
# 11            CESAR MAIA     DEM     ELEITO POR QP    494
# 12        TARCêSIO MOTTA    PSOL     ELEITO POR QP    488
# 13       PAULINHO DO CPX     PTN          SUPLENTE    422
# 14   ALEXANDRE ISQUIERDO     DEM     ELEITO POR QP    411
# ...

# %%
zona22 = tabela.loc[tabela['zona'] == '22']
zona22_agg = zona22.groupby(['candidato','partido','situacao']).agg({'votos': sum}).sort_values(by='votos', ascending = False).reset_index()
zona22_agg.head(20)
# Out:
#                     candidato partido          situacao  votos
# 0              ROSA FERNANDES    PMDB     ELEITO POR QP  10749
# 1                         VAL     PEN     ELEITO POR QP   5463
# 2                   VERA LINS      PP     ELEITO POR QP   2699
# 3            CARLOS BOLSONARO     PSC     ELEITO POR QP   1208
# 4              TARCêSIO MOTTA    PSOL     ELEITO POR QP    901
# 5                  CESAR MAIA     DEM     ELEITO POR QP    668
# 6                    LAURINHO     PTB          SUPLENTE    566
# 7                FABIO CARINO     PMN          SUPLENTE    525
# 8         ALEXANDRE ISQUIERDO     DEM     ELEITO POR QP    498
# 9             MARCIA TEIXEIRA     PSD          SUPLENTE    463
# 10         BISPO INALDO SILVA     PRB     ELEITO POR QP    409
# 11            MARIELLE FRANCO    PSOL     ELEITO POR QP    345
# 12       DONA REGINA DO IRAJA     PDT          SUPLENTE    334
# 13          DR. EDUARDO MOURA    PMDB          SUPLENTE    295
# ...

# %%
zona160 = tabela.loc[tabela['zona'] == '160']
zona160_agg = zona160.groupby(['candidato','partido','situacao']).agg({'votos': sum}).sort_values(by='votos', ascending = False).reset_index()
zona160_agg.head(20)
# Out:
#               candidato partido       situacao  votos
# 0           JOÌO CABRAL    PMDB       SUPLENTE   2497
# 1        ROSA FERNANDES    PMDB  ELEITO POR QP   1429
# 2     ALTAMIR DA NERVAL     PTB       SUPLENTE   1326
# 3    DELON DA JUVENTUDE      PP       SUPLENTE    830
# 4        TARCêSIO MOTTA    PSOL  ELEITO POR QP    717
# 5      CARLOS BOLSONARO     PSC  ELEITO POR QP    683
# 6                   DEL      PR     NÌO ELEITO    616
# 7        TERESA BERGHER    PSDB  ELEITO POR QP    533
# 8   ALEXANDRE ISQUIERDO     DEM  ELEITO POR QP    532
# 9            CESAR MAIA     DEM  ELEITO POR QP    512
# 10                 NINO     PTN       SUPLENTE    474
# 11      MARIELLE FRANCO    PSOL  ELEITO POR QP    459
# 12   BISPO INALDO SILVA     PRB  ELEITO POR QP    455
# 13      JARBAS OLIVEIRA     DEM       SUPLENTE    412
# 14     MARCELLO BARBOSA     DEM       SUPLENTE    398
# 15            VERA LINS      PP  ELEITO POR QP    327
# ...

# %%
zona161 = tabela.loc[tabela['zona'] == '161']
zona161_agg = zona161.groupby(['candidato','partido','situacao']).agg({'votos': sum}).sort_values(by='votos', ascending = False).reset_index()
zona161_agg.head(20)
# Out:
#               candidato partido          situacao  votos
# 0                   DEL      PR        NÌO ELEITO   8058
# 1        TERESA BERGHER    PSDB     ELEITO POR QP   6206
# 2       JARBAS OLIVEIRA     DEM          SUPLENTE   2128
# 3           JOÌO CABRAL    PMDB          SUPLENTE   1783
# 4       MARIELLE FRANCO    PSOL     ELEITO POR QP   1688
# 5      CARLOS BOLSONARO     PSC     ELEITO POR QP   1139
# 6            JAIME MELO     PDT          SUPLENTE   1013
# 7    DELON DA JUVENTUDE      PP          SUPLENTE   1005
# 8     OTONI DE PAULA JR     PSC     ELEITO POR QP    931
# 9         TåNIA BASTOS'     PRB     ELEITO POR QP    903
# 10   BISPO INALDO SILVA     PRB     ELEITO POR QP    730
# 11          MC TABAJARA     PHS          SUPLENTE    726
# 12       TARCêSIO MOTTA    PSOL     ELEITO POR QP    681
# 13     FERNANDO WILLIAM     PDT  ELEITO POR MDIA    600
# 14           CESAR MAIA     DEM     ELEITO POR QP    568
# ...

# %%
zona169 = tabela.loc[tabela['zona'] == '169']
zona169_agg = zona169.groupby(['candidato','partido','situacao']).agg({'votos': sum}).sort_values(by='votos', ascending = False).reset_index()
zona169_agg.head(20)
# Out:
#                        candidato  partido       situacao  votos
# 0                       EDUARDÌO     PMDB       SUPLENTE   1642
# 1   CASSETTI DO PARQUE MADUREIRA  PT do B       SUPLENTE   1123
# 2                    JOÌO CABRAL     PMDB       SUPLENTE   1076
# 3                 ROSA FERNANDES     PMDB  ELEITO POR QP   1018
# 4               CARLOS BOLSONARO      PSC  ELEITO POR QP    906
# 5           JOÌO MENDES DE JESUS      PRB  ELEITO POR QP    865
# 6                 TARCêSIO MOTTA     PSOL  ELEITO POR QP    755
# 7                           KIKO      PPS       SUPLENTE    725
# 8                     CESAR MAIA      DEM  ELEITO POR QP    704
# 9             DR. CARLOS EDUARDO       SD  ELEITO POR QP    678
# 10                  JORGINHO SOS     PMDB       SUPLENTE    586
# 11            BISPO INALDO SILVA      PRB  ELEITO POR QP    492
# 12                 KITTO DO POVO      PTN       SUPLENTE    453
# 13               MARIELLE FRANCO     PSOL  ELEITO POR QP    433
# ...

# %%
zona190 = tabela.loc[tabela['zona'] == '190']
zona190_agg = zona21.groupby(['candidato','partido','situacao']).agg({'votos': sum}).sort_values(by='votos', ascending = False).reset_index()
zona190_agg.head(20)
# Out:
#                candidato partido          situacao  votos
# 0       LUCIANO MEDEIROS     DEM          SUPLENTE   2853
# 1           JORGINHO SOS    PMDB          SUPLENTE   2615
# 2     PROFESSOR CALVINHO     PSD          SUPLENTE   1867
# 3   JOÌO MENDES DE JESUS     PRB     ELEITO POR QP   1433
# 4         GESIEL O PINGO     PRP        NÌO ELEITO   1047
# 5            JOÌO CABRAL    PMDB          SUPLENTE   1013
# 6       CARLOS BOLSONARO     PSC     ELEITO POR QP    824
# 7               AMIGO D      PR        NÌO ELEITO    753
# 8       ROBERTO TEIXEIRA     PSD          SUPLENTE    684
# 9         ROSA FERNANDES    PMDB     ELEITO POR QP    597
# 10    DR. CARLOS EDUARDO      SD     ELEITO POR QP    585
# 11            CESAR MAIA     DEM     ELEITO POR QP    494
# 12        TARCêSIO MOTTA    PSOL     ELEITO POR QP    488
# 13       PAULINHO DO CPX     PTN          SUPLENTE    422
# 14   ALEXANDRE ISQUIERDO     DEM     ELEITO POR QP    411
# ...

# %%
#A partir das linhas abaixo, são as zonas onde Marielle foi mais votada:

zona16 = tabela.loc[tabela['zona'] == '16']
zona16_agg = zona16.groupby(['candidato','partido','situacao']).agg({'votos': sum}).sort_values(by='votos', ascending = False).reset_index()
zona16_agg.head(20)
# Out:
#               candidato partido          situacao  votos
# 0        TARCêSIO MOTTA    PSOL     ELEITO POR QP   2944
# 1       MARIELLE FRANCO    PSOL     ELEITO POR QP   2237
# 2     LEILA DO FLAMENGO    PMDB          SUPLENTE   1974
# 3          LEANDRO LYRA    NOVO     ELEITO POR QP   1038
# 4            CESAR MAIA     DEM     ELEITO POR QP    835
# 5          RENATO CINCO    PSOL     ELEITO POR QP    733
# 6      CARLOS BOLSONARO     PSC     ELEITO POR QP    685
# 7        TERESA BERGHER    PSDB     ELEITO POR QP    620
# 8         RENATA GUERRA    NOVO          SUPLENTE    613
# 9               REIMONT      PT     ELEITO POR QP    590
# 10       PAULO PINHEIRO    PSOL     ELEITO POR QP    569
# 11          BRUNO RAMOS    PMDB          SUPLENTE    478
# 12        NILCEA FREIRE    PSOL          SUPLENTE    436
# 13  GILBERTO RODOVIARIO     PMN          SUPLENTE    364
# 14               ARRAES    PSDB          SUPLENTE    353
# ...

# %%
zona4 = tabela.loc[tabela['zona'] == '4']
zona4_agg = zona4.groupby(['candidato','partido','situacao']).agg({'votos': sum}).sort_values(by='votos', ascending = False).reset_index()
zona4_agg.head(20)
# Out:
#              candidato partido          situacao  votos
# 0       TARCêSIO MOTTA    PSOL     ELEITO POR QP   2427
# 1      MARIELLE FRANCO    PSOL     ELEITO POR QP   1926
# 2         LEANDRO LYRA    NOVO     ELEITO POR QP   1298
# 3           CESAR MAIA     DEM     ELEITO POR QP    947
# 4        RENATA GUERRA    NOVO          SUPLENTE    916
# 5     CARLOS BOLSONARO     PSC     ELEITO POR QP    736
# 6    LEILA DO FLAMENGO    PMDB          SUPLENTE    683
# 7               ARRAES    PSDB          SUPLENTE    644
# 8       PAULO PINHEIRO    PSOL     ELEITO POR QP    566
# 9         RENATO CINCO    PSOL     ELEITO POR QP    548
# 10             REIMONT      PT     ELEITO POR QP    436
# 11        MARCELO ARAR     PTB     ELEITO POR QP    413
# 12      TERESA BERGHER    PSDB     ELEITO POR QP    394
# 13         BRUNO RAMOS    PMDB          SUPLENTE    391
# 14       TåNIA BASTOS'     PRB     ELEITO POR QP    366
# 15       NILCEA FREIRE    PSOL          SUPLENTE    320
# ...

# %%
zona212 = tabela.loc[tabela['zona'] == '212']
zona212_agg = zona212.groupby(['candidato','partido','situacao']).agg({'votos': sum}).sort_values(by='votos', ascending = False).reset_index()
zona212_agg.head(20)
# Out:
#              candidato partido       situacao  votos
# 0         LEANDRO LYRA    NOVO  ELEITO POR QP   1197
# 1      MARIELLE FRANCO    PSOL  ELEITO POR QP    996
# 2        RENATA GUERRA    NOVO       SUPLENTE    930
# 3       TARCêSIO MOTTA    PSOL  ELEITO POR QP    881
# 4               ARRAES    PSDB       SUPLENTE    492
# 5       PAULO PINHEIRO    PSOL  ELEITO POR QP    471
# 6           CESAR MAIA     DEM  ELEITO POR QP    449
# 7     CARLOS BOLSONARO     PSC  ELEITO POR QP    362
# 8       TERESA BERGHER    PSDB  ELEITO POR QP    279
# 9       RAPHAEL GATTçS      PP       SUPLENTE    246
# 10    SALATHIEL SALADA     PTN       SUPLENTE    241
# 11        RENATO CINCO    PSOL  ELEITO POR QP    227
# 12       NILCEA FREIRE    PSOL       SUPLENTE    211
# 13             REIMONT      PT  ELEITO POR QP    209
# 14      LUCIANA CALAA     PRB       SUPLENTE    167
# 15            PORTINHO     PSD       SUPLENTE    164
# 16         BRUNO RAMOS    PMDB       SUPLENTE    149
# ...

# %%
zona166 = tabela.loc[tabela['zona'] == '166']
zona166_agg = zona166.groupby(['candidato','partido','situacao']).agg({'votos': sum}).sort_values(by='votos', ascending = False).reset_index()
zona166_agg.head(20)
# Out:
#                          candidato partido          situacao  votos
# 0                   TARCêSIO MOTTA    PSOL     ELEITO POR QP   1630
# 1                  MARIELLE FRANCO    PSOL     ELEITO POR QP   1170
# 2                     LEANDRO LYRA    NOVO     ELEITO POR QP    940
# 3                LEILA DO FLAMENGO    PMDB          SUPLENTE    868
# 4                 CARLOS BOLSONARO     PSC     ELEITO POR QP    775
# 5                       CESAR MAIA     DEM     ELEITO POR QP    754
# 6                      BRUNO RAMOS    PMDB          SUPLENTE    459
# 7                    RENATA GUERRA    NOVO          SUPLENTE    448
# 8                     RENATO CINCO    PSOL     ELEITO POR QP    373
# 9           RAFAEL ALOISIO FREITAS    PMDB     ELEITO POR QP    333
# 10                  PAULO PINHEIRO    PSOL     ELEITO POR QP    291
# 11                         REIMONT      PT     ELEITO POR QP    270
# 12                  TERESA BERGHER    PSDB     ELEITO POR QP    270
# ...

# %%
zona3 = tabela.loc[tabela['zona'] == '3']
zona3_agg = zona3.groupby(['candidato','partido','situacao']).agg({'votos': sum}).sort_values(by='votos', ascending = False).reset_index()
zona3_agg.head(20)
# Out:
#               candidato partido          situacao  votos
# 0     LEILA DO FLAMENGO    PMDB          SUPLENTE   2974
# 1        TARCêSIO MOTTA    PSOL     ELEITO POR QP   2072
# 2       MARIELLE FRANCO    PSOL     ELEITO POR QP   1286
# 3            CESAR MAIA     DEM     ELEITO POR QP    838
# 4        TERESA BERGHER    PSDB     ELEITO POR QP    815
# 5          LEANDRO LYRA    NOVO     ELEITO POR QP    737
# 6      CARLOS BOLSONARO     PSC     ELEITO POR QP    623
# 7         RENATA GUERRA    NOVO          SUPLENTE    524
# 8        PAULO PINHEIRO    PSOL     ELEITO POR QP    422
# 9          RENATO CINCO    PSOL     ELEITO POR QP    389
# 10              REIMONT      PT     ELEITO POR QP    378
# 11               ARRAES    PSDB          SUPLENTE    256
# 12          BRUNO RAMOS    PMDB          SUPLENTE    234
# 13        NILCEA FREIRE    PSOL          SUPLENTE    217
# 14      GEORGETTE VIDOR     PPS          SUPLENTE    201
# ...

# %%
zona164 = tabela.loc[tabela['zona'] == '164']
zona164_agg = zona164.groupby(['candidato','partido','situacao']).agg({'votos': sum}).sort_values(by='votos', ascending = False).reset_index()
zona164_agg.head(20)
# Out:
#               candidato partido          situacao  votos
# 0      EMIDIO DO BADALO     PTB          SUPLENTE   1596
# 1        TARCêSIO MOTTA    PSOL     ELEITO POR QP   1002
# 2       MARIELLE FRANCO    PSOL     ELEITO POR QP    907
# 3            DUDA PETRA     PDT          SUPLENTE    641
# 4   GILBERTO RODOVIARIO     PMN          SUPLENTE    608
# 5      CARLOS BOLSONARO     PSC     ELEITO POR QP    423
# 6            CESAR MAIA     DEM     ELEITO POR QP    325
# 7          RENATO CINCO    PSOL     ELEITO POR QP    323
# 8         TåNIA BASTOS'     PRB     ELEITO POR QP    308
# 9               REIMONT      PT     ELEITO POR QP    291
# 10         SOLANGE ROSA     PHS          SUPLENTE    268
# 11       SOLANGE AMARAL    PMDB          SUPLENTE    212
# 12    LEILA DO FLAMENGO    PMDB          SUPLENTE    199
# 13       LUCIANA NOVAES      PT     ELEITO POR QP    190
# 14         CARLO CAIADO     DEM     ELEITO POR QP    178
# ...

# %%
zona163 = tabela.loc[tabela['zona'] == '163']
zona163_agg = zona163.groupby(['candidato','partido','situacao']).agg({'votos': sum}).sort_values(by='votos', ascending = False).reset_index()
zona163_agg.head(20)
# Out:
#               candidato partido          situacao  votos
# 0     LEILA DO FLAMENGO    PMDB          SUPLENTE   2173
# 1        TARCêSIO MOTTA    PSOL     ELEITO POR QP   1878
# 2       MARIELLE FRANCO    PSOL     ELEITO POR QP   1113
# 3            CESAR MAIA     DEM     ELEITO POR QP    796
# 4         TIA TERESINHA    PRTB          SUPLENTE    670
# 5      CARLOS BOLSONARO     PSC     ELEITO POR QP    636
# 6           BRUNO RAMOS    PMDB          SUPLENTE    494
# 7               REIMONT      PT     ELEITO POR QP    415
# 8          RENATO CINCO    PSOL     ELEITO POR QP    381
# 9        PAULO PINHEIRO    PSOL     ELEITO POR QP    314
# 10         LEANDRO LYRA    NOVO     ELEITO POR QP    267
# 11     DR. JOÌO RICARDO    PMDB  ELEITO POR MDIA    265
# 12       TERESA BERGHER    PSDB     ELEITO POR QP    246
# 13  LEONEL BRIZOLA NETO    PSOL  ELEITO POR MDIA    236
# 14        TåNIA BASTOS'     PRB     ELEITO POR QP    223
# ...
